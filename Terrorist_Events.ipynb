# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
from matplotlib import pyplot as plt
import getpass

# %%
user = input("User Name: ")
password = getpass.getpass("Password: ")
hostname = input("Hostname: ")
database_name = input("Database: ")
schema = input("Schema: ")
# Out:
# User Name: trevorb
# Password: ········
# Hostname: 24.19.48.89
# Database: datadazed
# Schema: machine_learning

# %%
connection_string = 'postgresql://{0}:{1}@{2}/{3}'.format(user, password, hostname, database_name)
terrorist_events = dd.read_sql_table('global_terrorism_events', connection_string, index_col='eventid', schema=schema)

# %%
print("Number of partitions: " + str(terrorist_events.npartitions))
terrorist_events = terrorist_events.fillna(0)

terrorist_events
# Out:
# Number of partitions: 3
# Dask DataFrame Structure:
# ...

# %%
missing_values = terrorist_events.isnull().sum()
missing_values
# Out:
# Dask Series Structure:
# npartitions=1
# addnotes         int64
# weaptype4_txt      ...
# dtype: int64
# Dask Name: dataframe-sum-agg, 19 tasks

# %%
missing_count = ((missing_values/terrorist_events.index.size)/100)
missing_count
missing_count.visualize()

# %%
with ProgressBar():
    missing_count_pct = missing_count.compute()
missing_count_pct
# Out:
# [                                        ] | 0% Completed |  1min 38.5s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-55b5c0d66ede> in <module>
#       1 with ProgressBar():
# ----> 2     missing_count_pct = missing_count.compute()
#       3 missing_count_pct
#
# ~/opt/miniconda3/lib/python3.7/site-packages/dask/base.py in compute(self, **kwargs)
#     163         dask.base.compute
#     164         """
# --> 165         (result,) = compute(self, traverse=False, **kwargs)
#     166         return result
#     167
#
# ~/opt/miniconda3/lib/python3.7/site-packages/dask/base.py in compute(*args, **kwargs)
#     434     keys = [x.__dask_keys__() for x in collections]
#     435     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 436     results = schedule(dsk, keys, **kwargs)
# ...
